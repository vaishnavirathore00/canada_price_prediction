# %% [markdown]
# # price prediction using linear regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model

# %%
df=pd.read_csv('canada_per_capita_income.csv')
df.head(5)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
# scatter plot used for to numerical vairables
# %matplotlib inline
plt.scatter(df['year'],df['per capita income (US$)'], color='purple',marker='+')
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
# Out:
# Text(0, 0.5, 'per capita income (US$)')

# %%
# %matplotlib inline
plt.scatter(df['year'],df['per capita income (US$)'], color='purple',marker='+')
plt.xlabel('year', fontsize=20)
plt.ylabel('per capita income (US$)', fontsize=16)
plt.plot(df.year,reg.predict(df[['year']]),color='orange')

# %% [markdown]
# # creating object to use linear regression

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']],df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
reg.predict([[1969]])
# Out:
# array([-963.02474194])

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# -1632210.7578554575

# %% [markdown]
# # create a dataframe

# %%
d=df.copy(deep=True)
d=pd.read_csv('canada_per_capita_income.csv',)
del d['per capita income (US$)']
d
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
p = reg.predict(d)

# %%
d['prices'] = p

# %%
d
# Out:
#     year        prices
# 0   1970   -134.559667
# 1   1971    693.905409
# 2   1972   1522.370484
# 3   1973   2350.835559
# 4   1974   3179.300634
# 5   1975   4007.765709
# 6   1976   4836.230785
# 7   1977   5664.695860
# 8   1978   6493.160935
# 9   1979   7321.626010
# 10  1980   8150.091086
# 11  1981   8978.556161
# 12  1982   9807.021236
# 13  1983  10635.486311
# 14  1984  11463.951386
# 15  1985  12292.416462
# 16  1986  13120.881537
# 17  1987  13949.346612
# 18  1988  14777.811687
# 19  1989  15606.276763
# 20  1990  16434.741838
# 21  1991  17263.206913
# 22  1992  18091.671988
# 23  1993  18920.137063
# 24  1994  19748.602139
# 25  1995  20577.067214
# 26  1996  21405.532289
# 27  1997  22233.997364
# 28  1998  23062.462440
# 29  1999  23890.927515
# 30  2000  24719.392590
# 31  2001  25547.857665
# 32  2002  26376.322740
# 33  2003  27204.787816
# 34  2004  28033.252891
# 35  2005  28861.717966
# 36  2006  29690.183041
# 37  2007  30518.648117
# 38  2008  31347.113192
# ...

# %%
d.to_csv('canada_prediction.csv')

# %% [markdown]
# # predicting price for year 2020

# %%
reg.predict([[2020]])
# Out:
# array([41288.69409442])
